# %% [markdown]
# # Joining the two datasets together

# %%
from google.colab import drive
import os
import pandas as pd
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
#Script to merge Dublin Airport flight data with corresponding METAR weather observations.
#Steps:
#1. Load and time-align flight and weather data using merge_asof.
#2. Perform feature engineering (hour, weekday).
#3. Label encode categorical columns.
#4. Save final dataset ready for ML.

# %%
drive.mount('/content/drive')
#connecting to the google drive
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/Final Year Project/Data/Joined Datasets')
# !pwd
#make sure operating in correct directory
# Out:
# /content/drive/MyDrive/Final Year Project/Data/Joined Datasets

# %%
weather = pd.read_csv('sorted_output.csv')
flights = pd.read_csv('Flight_to_ml.csv')
weather.head()# import the weather and the flights dataset seperately and display them to make sure they right
# Out:
#   Station     Observation Time  Wind Speed (KT)  Visibility (m)  \
# 0    EIDW  2024-03-01 00:00:00                8         10000.0
# 1    EIDW  2024-03-01 00:30:00                6         10000.0
# 2    EIDW  2024-03-01 01:00:00                8         10000.0
# 3    EIDW  2024-03-01 01:30:00                9         10000.0
# 4    EIDW  2024-03-01 02:00:00                9         10000.0
#
#    Temperature (C)  Dew Point (C)  Pressure (hPa)  Humidity (%)
# 0                4              0             991         75.17
# 1                4              1             990         80.80
# 2                4              2             989         86.80
# 3                4              2             988         86.80
# 4                4              2             987         86.80

# %%
flights.head() # display the flights dataset
# Out:
#          Date Flight Number          Airline Aircraft Model  \
# 0  2024-03-01        BA7872  British Airways           A320
# 1  2024-03-01         EI778       Aer Lingus           A320
# 2  2024-03-01        FR5910          Ryanair           B737
# 3  2024-03-01        FR7124          Ryanair           B737
# 4  2024-03-01        FR3995          Ryanair           B737
#
#       Departure Airport        Scheduled Departure        Estimated Departure  \
# 0  Dublin International  2024-03-01 12:10:00+00:00  2024-03-01 12:10:00+00:00
# 1  Dublin International  2024-03-01 12:50:00+00:00  2024-03-01 12:50:00+00:00
# 2  Dublin International  2024-03-01 07:35:00+00:00  2024-03-01 07:35:00+00:00
# 3  Dublin International  2024-03-01 11:55:00+00:00  2024-03-01 11:55:00+00:00
# 4  Dublin International  2024-03-01 06:00:00+00:00  2024-03-01 06:00:00+00:00
#
#             Actual Departure  Departure Terminal Departure Gate  ...  \
# 0  2024-03-01 14:01:00+00:00                 1.0            207  ...
# 1  2024-03-01 13:54:00+00:00                 2.0           335E  ...
# 2  2024-03-01 08:38:00+00:00                 1.0            107  ...
# 3  2024-03-01 13:29:00+00:00                 1.0            108  ...
# 4  2024-03-01 06:11:00+00:00                 1.0            110  ...
#
#    Aircraft Size Delayed  Flight Duration Flight Duration (Hours)  \
# 0            1.0       1  0 days 01:20:00                1.333333
# 1            1.0       1  0 days 04:20:00                4.333333
# 2            1.0       1  0 days 04:10:00                4.166667
# 3            1.0       1  0 days 04:10:00                4.166667
# 4            1.0       0  0 days 04:50:00                4.833333
#
#   Flight Duration (Minutes)  departure_time  departure_date peak_hour  \
# 0                      80.0        12:10:00      2024-03-01         0
# 1                     260.0        12:50:00      2024-03-01         0
# 2                     250.0        07:35:00      2024-03-01         1
# 3                     250.0        11:55:00      2024-03-01         0
# 4                     290.0        06:00:00      2024-03-01         1
#
#    busiest_day  peak_season
# 0            1            0
# 1            1            0
# 2            1            0
# 3            1            0
# 4            1            0
#
# [5 rows x 25 columns]

# %%
# Convert datetime columns to proper format with UTC timezone in both datasets
flights['Scheduled Departure'] = pd.to_datetime(flights['Scheduled Departure'], utc=True)
weather['Observation Time'] = pd.to_datetime(weather['Observation Time'], utc=True)

# Merge using nearest timestamp matching
merged_df = pd.merge_asof(
    flights.sort_values("Scheduled Departure"),
    weather.sort_values("Observation Time"),
    left_on="Scheduled Departure",
    right_on="Observation Time",
    direction="backward" )
# - Ensure flight data is sorted
# - Ensure weather data is sorted
# - Flight departure times
# - Weather observation times
# - Assign closest past weather reading

print("Merging complete! The final dataset is saved as 'final_ml_dataset.csv'.")
# Out:
# Merging complete! The final dataset is saved as 'final_ml_dataset.csv'.

# %%
merged_df.head() # display the completed dataset
# Out:
#          Date Flight Number                 Airline Aircraft Model  \
# 0  2024-03-01        FR7044                 Ryanair           B737
# 1  2024-03-01        MF9760         Xiamen Airlines           B737
# 2  2024-03-01        MU1898  China Eastern Airlines           A320
# 3  2024-03-01         KQ932           Kenya Airways           B737
# 4  2024-03-01        DL9609         Delta Air Lines           B767
#
#       Departure Airport       Scheduled Departure        Estimated Departure  \
# 0  Dublin International 2024-03-01 05:45:00+00:00  2024-03-01 05:45:00+00:00
# 1  Dublin International 2024-03-01 05:55:00+00:00  2024-03-01 05:55:00+00:00
# 2  Dublin International 2024-03-01 05:55:00+00:00  2024-03-01 05:55:00+00:00
# 3  Dublin International 2024-03-01 05:55:00+00:00  2024-03-01 05:55:00+00:00
# 4  Dublin International 2024-03-01 05:55:00+00:00  2024-03-01 05:55:00+00:00
#
#             Actual Departure  Departure Terminal Departure Gate  ...  \
# 0  2024-03-01 06:02:00+00:00                 1.0            107  ...
# 1  2024-03-01 06:24:00+00:00                 1.0            306  ...
# 2  2024-03-01 06:24:00+00:00                 1.0            306  ...
# 3  2024-03-01 06:24:00+00:00                 1.0            306  ...
# 4  2024-03-01 06:24:00+00:00                 1.0            306  ...
#
#    busiest_day peak_season Station          Observation Time Wind Speed (KT)  \
# 0            1           0    EIDW 2024-03-01 05:30:00+00:00              14
# 1            1           0    EIDW 2024-03-01 05:30:00+00:00              14
# 2            1           0    EIDW 2024-03-01 05:30:00+00:00              14
# 3            1           0    EIDW 2024-03-01 05:30:00+00:00              14
# 4            1           0    EIDW 2024-03-01 05:30:00+00:00              14
#
#    Visibility (m)  Temperature (C) Dew Point (C)  Pressure (hPa)  Humidity (%)
# 0         10000.0                4             3             983          93.2
# 1         10000.0                4             3             983          93.2
# 2         10000.0                4             3             983          93.2
# 3         10000.0                4             3             983          93.2
# 4         10000.0                4             3             983          93.2
#
# [5 rows x 33 columns]

# %%
file_save = 'test.csv' # Save a test version of the merged dataset
merged_df.to_csv(file_save, index=False)

# %% [markdown]
# # Preparing full dataset for machine learning

# %%
# Load the full dataset
ml_df = pd.read_csv("test.csv")

# Convert datetime columns to proper format to make sure
ml_df['Scheduled Departure'] = pd.to_datetime(ml_df['Scheduled Departure'], utc=True)

# Extract hour and day of the week for better ML performance to individual columns
ml_df['hour_of_day'] = ml_df['Scheduled Departure'].dt.hour
ml_df['day_of_week'] = ml_df['Scheduled Departure'].dt.dayofweek

# Dropped unnecessary columns that are not useful for ML
ml_df.drop(columns=['Date', 'Scheduled Departure', 'Estimated Departure', 'Actual Departure',
                    'Scheduled Arrival', 'Estimated Arrival', 'Actual Arrival',
                    'departure_time', 'departure_date', 'Observation Time', 'Station', 'Flight Duration', 'Departure Delay'], inplace=True)

# Identify categorical columns in the full dataset
categorical_columns = ['Flight Number', 'Airline', 'Aircraft Model', 'Departure Airport',
                       'Departure Gate', 'Arrival Airport']

# Apply Label Encoding for categorical columns so they can be used for ML
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    ml_df[col] = le.fit_transform(ml_df[col])
    label_encoders[col] = le

#final dataset ready for ML now
ml_df.to_csv("final_ml_ready_dataset.csv", index=False)

print("Dataset is now fully prepared for machine learning! Saved as 'final_ml_ready_dataset.csv'.")
# Out:
# Dataset is now fully prepared for machine learning! Saved as 'final_ml_ready_dataset.csv'.
